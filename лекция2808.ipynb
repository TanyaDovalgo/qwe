# %% [markdown]
# <a href="https://colab.research.google.com/github/TanyaDovalgo/qwe/blob/main/%D0%BB%D0%B5%D0%BA%D1%86%D0%B8%D1%8F2808.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.DataFrame({'x':[1,3,2],'y':[2,4,1]})

# %%
df.drop(1,axis=0,inplace=True)

# %%
df
# Out:
#    x  y
# 0  1  2
# 2  2  1

# %%
del df['x']

# %%
df
# Out:
#    y
# 0  2
# 2  1

# %%
df.reset_index(drop=True)
# Out:
#    y
# 0  2
# 1  1

# %%
df1=pd.DataFrame({'x':[3,2,3],'y':[0,2,2]})

# %%
df2=pd.DataFrame({'x':[1,2,3],'y':[0,5,2]})

# %%
print(df1>=df2)
# Out:
#       x      y
# 0  True   True
# 1  True  False
# 2  True   True

# %%
df1[df1>1]
# Out:
#    x    y
# 0  3  NaN
# 1  2  2.0
# 2  3  2.0

# %%
df2[(df2<2)&(df2>0)]
# Out:
#      x   y
# 0  1.0 NaN
# 1  NaN NaN
# 2  NaN NaN

# %%
df2[(df2<2)|(df2>0)]
# Out:
#    x  y
# 0  1  0
# 1  2  5
# 2  3  2

# %%
data={'Имя':['Анна','Борис', None,'Джон'],'Возраст':[25,30,28,None]}
df=pd.DataFrame(data)

# %%
df
# Out:
#      Имя  Возраст
# 0   Анна     25.0
# 1  Борис     30.0
# 2   None     28.0
# 3   Джон      NaN

# %%
df.isnull()
# Out:
#      Имя  Возраст
# 0  False    False
# 1  False    False
# 2   True    False
# 3  False     True

# %%
x=df.isnull()
df.isnull().loc[x['Имя'] == True]
# Out:
#     Имя  Возраст
# 2  True    False

# %%
data={'Цвет':['Красный',"Синий','Красный']}
df=pf.dataframe(data)
unique_color=df
